# %% [markdown]
# # MAHATMA GANDHI CENTRAL UNIVERSITY
# ## IRIS DATASET PROJECT
# ### Name - Rishita Srivastava
# ### En.no.- MGCU2020CSIT3023
# ### Course - Machine Learning
# ### Programme of Study - B.Tech(5th Semester)

# %%
import pandas as pd
data = pd.read_csv("C:/Users/HP/OneDrive/Desktop/pyhton proj/iris.csv")

# %%
data.shape
# Out:
# (150, 6)

# %%
data.head(150)
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['Id', 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### to display basic info about datatype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           150 non-null    int64
#  1   SepalLength  150 non-null    float64
#  2   SepalWidth   150 non-null    float64
#  3   PetalLength  150 non-null    float64
#  4   PetalWidth   150 non-null    float64
#  5   Species      150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_species = data.groupby('Species')

# %% [markdown]
# ### to display stats about data

# %%
data.describe()
# Out:
#                Id  SepalLength  SepalWidth  PetalLength  PetalWidth
# count  150.000000   150.000000  150.000000   150.000000  150.000000
# mean    75.500000     5.843333    3.054000     3.758667    1.198667
# std     43.445368     0.828066    0.433594     1.764420    0.763161
# min      1.000000     4.300000    2.000000     1.000000    0.100000
# 25%     38.250000     5.100000    2.800000     1.600000    0.300000
# 50%     75.500000     5.800000    3.000000     4.350000    1.300000
# 75%    112.750000     6.400000    3.300000     5.100000    1.800000
# max    150.000000     7.900000    4.400000     6.900000    2.500000

# %%
iris_species.describe().T
# Out:
# Species            Iris-setosa  Iris-versicolor  Iris-virginica
# Id          count    50.000000        50.000000       50.000000
#             mean     25.500000        75.500000      125.500000
#             std      14.577380        14.577380       14.577380
#             min       1.000000        51.000000      101.000000
#             25%      13.250000        63.250000      113.250000
#             50%      25.500000        75.500000      125.500000
#             75%      37.750000        87.750000      137.750000
#             max      50.000000       100.000000      150.000000
# SepalLength count    50.000000        50.000000       50.000000
#             mean      5.006000         5.936000        6.588000
#             std       0.352490         0.516171        0.635880
#             min       4.300000         4.900000        4.900000
#             25%       4.800000         5.600000        6.225000
#             50%       5.000000         5.900000        6.500000
# ...

# %% [markdown]
# ### check for null values

# %%
data.isnull().sum()
# Out:
# Id             0
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64

# %% [markdown]
# #   List of plot function
# ### Line Plot
# ### Area Plot
# ### Bar Graph
# ### Hexbin Plot
# ### Boxplot
# ### Histogram
# ### Scatter Plot
# ### Pie chart
# ### Density

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns

# %%
data = pd.read_csv('iris.csv')

# %%
#to delete the column
data = data.drop(columns =['Id'])

# %% [markdown]
# # LINE PLOT

# %%
data.plot(kind='line', color=['green', 'red', 'blue', 'orange'], linewidth=1)
plt.show()

# %%
m=list(data['SepalLength'])
n = pd.DataFrame(m)
n.plot.line(title='Line_plot of SepalLength')
# Out:
# <AxesSubplot: title={'center': 'Line_plot of SepalLength'}>

# %%
m=list(data['SepalWidth'])
n = pd.DataFrame(m)
n.plot.line(title='Line_plot of SepalWidth', color='orange')
plt.show()

# %%
m=list(data['PetalLength'])
n = pd.DataFrame(m)
n.plot.line(title='Line_plot of PetalLength', color='green')
# Out:
# <AxesSubplot: title={'center': 'Line_plot of PetalLength'}>

# %%
m=list(data['PetalWidth'])
n = pd.DataFrame(m)
n.plot.line(title='Line_plot of PetalWidth', color='red')
# Out:
# <AxesSubplot: title={'center': 'Line_plot of PetalWidth'}>

# %% [markdown]
# # Line_plot of Iris-Setosa

# %%
n=data[0:50]
print(n)
n.plot.line()
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-setosa          5.1         3.5          1.4         0.2
# Iris-setosa          4.9         3.0          1.4         0.2
# Iris-setosa          4.7         3.2          1.3         0.2
# Iris-setosa          4.6         3.1          1.5         0.2
# Iris-setosa          5.0         3.6          1.4         0.2
# Iris-setosa          5.4         3.9          1.7         0.4
# Iris-setosa          4.6         3.4          1.4         0.3
# Iris-setosa          5.0         3.4          1.5         0.2
# Iris-setosa          4.4         2.9          1.4         0.2
# Iris-setosa          4.9         3.1          1.5         0.1
# Iris-setosa          5.4         3.7          1.5         0.2
# Iris-setosa          4.8         3.4          1.6         0.2
# Iris-setosa          4.8         3.0          1.4         0.1
# Iris-setosa          4.3         3.0          1.1         0.1
# ...

# %%
m=list(data['SepalLength'])
n=m[0:50]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['blue'], linewidth=1, title='SepalLength of Iris-Setosa')
plt.legend('SL')
plt.show()
# Out:
# 50

# %%
m=list(data['SepalWidth'])
n=m[0:50]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['orange'], linewidth=1, title='SepalWidth of Iris-Setosa')
plt.legend('SW')
plt.show()
# Out:
# 50

# %%
m=list(data['PetalLength'])
n=m[0:50]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['green'], linewidth=1, title='PetalLength of Iris-Setosa')
plt.legend('PL')
plt.show()
# Out:
# 50

# %%
m=list(data['PetalWidth'])
n=m[0:50]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['red'], linewidth=1, title='PetalWidth of Iris-Setosa')
plt.legend('PW')
plt.show()
# Out:
# 50

# %% [markdown]
# # Line_plot of Iris-Versicolor

# %%
n=data[50:100]
print(n)
print(len(n))
n.plot.line()
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-versicolor          7.0         3.2          4.7         1.4
# Iris-versicolor          6.4         3.2          4.5         1.5
# Iris-versicolor          6.9         3.1          4.9         1.5
# Iris-versicolor          5.5         2.3          4.0         1.3
# Iris-versicolor          6.5         2.8          4.6         1.5
# Iris-versicolor          5.7         2.8          4.5         1.3
# Iris-versicolor          6.3         3.3          4.7         1.6
# Iris-versicolor          4.9         2.4          3.3         1.0
# Iris-versicolor          6.6         2.9          4.6         1.3
# Iris-versicolor          5.2         2.7          3.9         1.4
# Iris-versicolor          5.0         2.0          3.5         1.0
# Iris-versicolor          5.9         3.0          4.2         1.5
# Iris-versicolor          6.0         2.2          4.0         1.0
# ...

# %%
m=list(data['SepalLength'])
n=m[50:100]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['blue'], linewidth=1, title='SepalLength of Iris-Versicolor')
plt.legend('SL')
plt.show()
# Out:
# 50

# %%
m=list(data['SepalWidth'])
n=m[50:100]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['orange'], linewidth=1, title='SepalWidth of Iris-Versicolor')
plt.legend('SW')
plt.show()
# Out:
# 50

# %%
m=list(data['PetalLength'])
n=m[50:100]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['green'], linewidth=1, title='PetalLength of Iris-Versicolor')
plt.legend('PL')
plt.show()
# Out:
# 50

# %%
m=list(data['PetalWidth'])
n=m[50:100]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['red'], linewidth=1, title='PetalWidth of Iris-Versicolor')
plt.legend('PW')
plt.show()
# Out:
# 50

# %% [markdown]
# # Line_plot of Iris-Virginica

# %%
n=data[100:150]
print(n)
print(len(n))
n.plot.line()
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-virginica          6.3         3.3          6.0         2.5
# Iris-virginica          5.8         2.7          5.1         1.9
# Iris-virginica          7.1         3.0          5.9         2.1
# Iris-virginica          6.3         2.9          5.6         1.8
# Iris-virginica          6.5         3.0          5.8         2.2
# Iris-virginica          7.6         3.0          6.6         2.1
# Iris-virginica          4.9         2.5          4.5         1.7
# Iris-virginica          7.3         2.9          6.3         1.8
# Iris-virginica          6.7         2.5          5.8         1.8
# Iris-virginica          7.2         3.6          6.1         2.5
# Iris-virginica          6.5         3.2          5.1         2.0
# Iris-virginica          6.4         2.7          5.3         1.9
# Iris-virginica          6.8         3.0          5.5         2.1
# ...

# %%
m=list(data['SepalLength'])
n=m[100:150]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['blue'], linewidth=1, title='SepalLength of Iris-Virginica')
plt.legend('SL')
plt.show()
# Out:
# 50

# %%
m=list(data['SepalWidth'])
n=m[100:150]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['orange'], linewidth=1, title='SepalWidth of Iris-Virginica')
plt.legend('SW')
plt.show()
# Out:
# 50

# %%
m=list(data['PetalLength'])
n=m[100:150]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['green'], linewidth=1, title='PetalLength of Iris-Virginica')
plt.legend('PL')
plt.show()
# Out:
# 50

# %%
m=list(data['PetalWidth'])
n=m[100:150]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='line', color=['red'], linewidth=1, title='PetalWidth of Iris-Virginica')
plt.legend('PW')
plt.show()
# Out:
# 50

# %% [markdown]
# # Area Plot

# %%
data.plot.area()
# Out:
# <AxesSubplot: >

# %%
m=list(data['SepalLength'])
n = pd.DataFrame(m)
n.plot.area(title='Area_plot of SepalLength')
# Out:
# <AxesSubplot: title={'center': 'Area_plot of SepalLength'}>

# %%
m=list(data['SepalWidth'])
n = pd.DataFrame(m)
n.plot.area(title='Area_plot of SepalWidth', color='orange')
# Out:
# <AxesSubplot: title={'center': 'Area_plot of SepalWidth'}>

# %%
m=list(data['PetalLength'])
n = pd.DataFrame(m)
n.plot.area(title='Area_plot of PetalLength', color='green')
# Out:
# <AxesSubplot: title={'center': 'Area_plot of PetalLength'}>

# %%
m=list(data['PetalWidth'])
n = pd.DataFrame(m)
n.plot.area(title='Area_plot of PetalWidth', color='darkred')
# Out:
# <AxesSubplot: title={'center': 'Area_plot of PetalWidth'}>

# %% [markdown]
# # Area_plot of Iris-Setosa

# %%
n=data[0:50]
n.plot.area( alpha=0.7)
# Out:
# <AxesSubplot: xlabel='Species'>

# %% [markdown]
# # Area_plot of Iris-versicolor

# %%
n=data[50:100]
n.plot.area( alpha=0.7)
# Out:
# <AxesSubplot: xlabel='Species'>

# %% [markdown]
# # Area_plot of Iris-Virginica

# %%
n=data[100:150]
n.plot.area( alpha=0.7)
# Out:
# <AxesSubplot: xlabel='Species'>

# %% [markdown]
# # BAR GRAPH

# %%
data.plot(kind='bar', width=2)
plt.show()

# %% [markdown]
# # Hexbin Plot

# %%
data.plot.hexbin(x='SepalLength', y='SepalWidth',gridsize= 25,cmap='Oranges')
# Out:
# <AxesSubplot: xlabel='SepalLength', ylabel='SepalWidth'>

# %%
data.plot.hexbin(x='PetalLength', y='PetalWidth',gridsize= 25,cmap='Greens')
# Out:
# <AxesSubplot: xlabel='PetalLength', ylabel='PetalWidth'>

# %%
data.plot.hexbin(x='SepalLength', y='PetalLength',gridsize= 25,cmap='Blues')
# Out:
# <AxesSubplot: xlabel='SepalLength', ylabel='PetalLength'>

# %%
data.plot.hexbin(x='SepalWidth', y='PetalWidth',gridsize= 25,cmap='Greys')
# Out:
# <AxesSubplot: xlabel='SepalWidth', ylabel='PetalWidth'>

# %% [markdown]
# # BOX PLOT

# %%
data = pd.DataFrame(data)
data.plot(kind='box', vert=True)
plt.show()

# %% [markdown]
# ## Box_plot of Iris-Setosa

# %%
n=data[0:50]
n.plot.box()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Box_plot of Iris-Versicolor

# %%
n=data[50:100]
n.plot.box()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Box_plot of Iris-Virginica

# %%
n=data[100:150]
n.plot.box()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # HISTOGRAM

# %%
data.plot.hist(bins = 50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
data['SepalLength'].hist()
# Out:
# <AxesSubplot: >

# %%
data['PetalLength'].hist()
# Out:
# <AxesSubplot: >

# %%
data['SepalWidth'].hist()
# Out:
# <AxesSubplot: >

# %%
data['PetalWidth'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Histogram of Irisi-Setosa

# %%
n=data[0:50]
n.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ## Histogram of Irisi-Versicolor

# %%
n=data[50:100]
n.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ## Histogram of Irisi-Virginica

# %%
n=data[100:150]
n.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# # SCATTER PLOT

# %%
colors = ['red', 'green', 'blue']
species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['SepalLength'], x['SepalWidth'], c= colors[i], label = species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['PetalLength'], x['PetalWidth'], c= colors[i], label = species[i])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['SepalLength'], x['PetalLength'], c= colors[i], label = species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()

# %%
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['SepalWidth'], x['PetalWidth'], c= colors[i], label = species[i])
plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.legend()

# %% [markdown]
# # PIE CHART

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('iris.csv')
data = data.drop(columns =['Id'])
data = data.set_index('Species')
a = list(data.columns)
a = a[0:4]
plt.figure(figsize= (6,8))
plt.pie(data.mean(0),labels =a, radius=1.5,autopct ="%2.1f%%")
plt.legend()
plt.show()

# %%
a = list(data.columns)
a = a[0:4]
plt.pie(data.mean(0),labels =a, explode=(0.1,0,0.1,0.3), radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7d7d80d0>,
# ...
#  [Text(0.42583275514894087, 1.6973999129970117, 'SepalLength'),
#   Text(-1.6168130223381074, -0.32926531976191337, 'SepalWidth'),
#   Text(0.3045211507651874, -1.7233011543942767, 'PetalLength'),
#   Text(1.8784130957196619, -0.5235114533884397, 'PetalWidth')],
#  [Text(0.2433330029422519, 0.9699428074268636, '42.2%'),
#   Text(-0.8818980121844221, -0.17959926532467999, '22.0%'),
#   Text(0.17401208615153563, -0.9847435167967293, '27.1%'),
#   Text(1.1559465204428687, -0.322160894392886, '8.7%')])

# %% [markdown]
# ## Pie_chart for Iris-Setosa

# %%
a = list(data.columns)
a = a[0:4]
b=data[0:50]
plt.pie(b.mean(0), labels=a, radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7d80f450>,
# ...
#  [Text(0.030694847676946562, 1.6497144681204956, 'SepalLength'),
#   Text(-0.8598968669954504, -1.4082178020929181, 'SepalWidth'),
#   Text(1.3568942150289822, -0.9387960850050892, 'PetalLength'),
#   Text(1.6452800726966506, -0.12471360145270635, 'PetalWidth')],
#  [Text(0.016742644187425396, 0.899844255338452, '49.4%'),
#   Text(-0.46903465472479106, -0.7681188011415916, '33.7%'),
#   Text(0.7401241172885356, -0.5120705918209576, '14.4%'),
#   Text(0.897425494198173, -0.06802560079238527, '2.4%')])

# %%
a = list(data.columns)
a = a[0:4]
b=data[0:50]
plt.pie(b.mean(0), labels=a, explode=(0.1,0,0.1,0.3), radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7d932b90>,
# ...
#  [Text(0.03255514147554939, 1.7496971631581013, 'SepalLength'),
#   Text(-0.8598968669954504, -1.4082178020929181, 'SepalWidth'),
#   Text(1.4391302280610416, -0.99569281742964, 'PetalLength'),
#   Text(1.9444219040960415, -0.14738880171683477, 'PetalWidth')],
#  [Text(0.018602937986028217, 0.9998269503760578, '49.4%'),
#   Text(-0.46903465472479106, -0.7681188011415916, '33.7%'),
#   Text(0.8223601303205951, -0.5689673242455084, '14.4%'),
#   Text(1.196567325597564, -0.09070080105651371, '2.4%')])

# %% [markdown]
# ## Pie_chart for Iris-Versicolor

# %%
a = list(data.columns)
a = a[0:4]
b=data[50:100]
plt.pie(b.mean(0), labels=a, radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7d89cc50>,
# ...
#  [Text(0.43370414618600556, 1.591980123488063, 'SepalLength'),
#   Text(-1.6451192287227812, -0.12681767734256047, 'SepalWidth'),
#   Text(0.08483308273835127, -1.6478177532946745, 'PetalLength'),
#   Text(1.580405080436179, -0.47415164423580225, 'PetalWidth')],
#  [Text(0.23656589791963933, 0.8683527946298525, '41.5%'),
#   Text(-0.8973377611215169, -0.06917327855048752, '19.4%'),
#   Text(0.046272590584555226, -0.8988096836152768, '29.8%'),
#   Text(0.8620391347833702, -0.2586281695831648, '9.3%')])

# %%
a = list(data.columns)
a = a[0:4]
b=data[50:100]
plt.pie(b.mean(0), labels=a, explode=(0.1,0,0.1,0.2), radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7db8e1d0>,
# ...
#  [Text(0.45998924595485435, 1.6884637673358245, 'SepalLength'),
#   Text(-1.6451192287227812, -0.12681767734256047, 'SepalWidth'),
#   Text(0.08997448169219074, -1.7476854959185941, 'PetalLength'),
#   Text(1.7719693326102615, -0.5316245708098388, 'PetalWidth')],
#  [Text(0.26285099768848813, 0.9648364384776139, '41.5%'),
#   Text(-0.8973377611215169, -0.06917327855048752, '19.4%'),
#   Text(0.0514139895383947, -0.9986774262391964, '29.8%'),
#   Text(1.0536033869574526, -0.31610109615720144, '9.3%')])

# %% [markdown]
# ## Pie_chart for Iris-Virginica

# %%
a = list(data.columns)
a = a[0:4]
b=data[100:150]
plt.pie(b.mean(0), labels=a, radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7d8d4e10>,
# ...
#  [Text(0.5863159540725675, 1.5423143654910225, 'SepalLength'),
#   Text(-1.6229099219710232, 0.29776397560485335, 'SepalWidth'),
#   Text(-0.3108424775674365, -1.620455785925595, 'PetalLength'),
#   Text(1.5375358244483868, -0.5987349902401065, 'PetalWidth')],
#  [Text(0.3198087022214004, 0.8412623811769212, '38.4%'),
#   Text(-0.8852235938023763, 0.16241671396628363, '17.4%'),
#   Text(-0.1695504423095108, -0.8838849741412336, '32.4%'),
#   Text(0.8386559042445745, -0.32658272194914895, '11.8%')])

# %%
a = list(data.columns)
a = a[0:4]
b=data[100:150]
plt.pie(b.mean(0), labels=a, explode=(0.1,0.1,0,0.3), radius=1.5,autopct ="%2.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba7e1c6e90>,
# ...
#  [Text(0.6218502543193898, 1.6357879633995693, 'SepalLength'),
#   Text(-1.721268099060176, 0.31581027715666266, 'SepalWidth'),
#   Text(-0.3108424775674365, -1.620455785925595, 'PetalLength'),
#   Text(1.8170877925299116, -0.7075958975564894, 'PetalWidth')],
#  [Text(0.35534300246822265, 0.934735979085468, '38.4%'),
#   Text(-0.9835817708915292, 0.1804630155180929, '17.4%'),
#   Text(-0.1695504423095108, -0.8838849741412336, '32.4%'),
#   Text(1.1182078723260993, -0.43544362926553193, '11.8%')])

# %% [markdown]
# # Bar plot for Iris-Setosa:-

# %%
import matplotlib.pyplot as plt
data = pd.read_csv('iris.csv')
data = data.drop(columns =['Id'])
data = pd.DataFrame(data)

# %% [markdown]
# ### Sample for bar_plot of iris-setosa by taking 5 data

# %%
a=data[0:5]
a.plot.bar()
# Out:
# <AxesSubplot: xlabel='Species'>

# %%
a=data[0:5]
a.plot.barh()
# Out:
# <AxesSubplot: ylabel='Species'>

# %% [markdown]
# ## Sepal-Length

# %%
m=list(data['SepalLength'])
print(m)
print(len(m))
n=m[0:50] #for Sepal-Length of Iris-Setosa
print(n)
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar')
plt.legend("SL")
plt.show()
# Out:
# [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5.0, 5.5, 4.9, 4.4, 5.1, 5.0, 4.5, 4.4, 5.0, 5.1, 4.8, 5.1, 4.6, 5.3, 5.0, 7.0, 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5.0, 5.9, 6.0, 6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7, 6.0, 5.7, 5.5, 5.5, 5.8, 6.0, 5.4, 6.0, 6.7, 6.3, 5.6, 5.5, 5.5, 6.1, 5.8, 5.0, 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]
# 150
# ...

# %% [markdown]
# ## Sepal-Width

# %%
m=list(data['SepalWidth'])
print(len(m))
n=m[0:50] #for Sepal-Width of Iris-Setosa
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['darkorange'])
plt.legend("SW")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# ## Petal-Length

# %%
m=list(data['PetalLength'])
print(len(m))
n=m[0:50] #for Petal-Length of Iris-Setosa
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['green'])
plt.legend("PL")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# ## Petal-Width

# %%
m=list(data['PetalWidth'])
print(len(m))
n=m[0:50] #for Petal-Width of Iris-Setosa
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['red'])
plt.legend("PW")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# # Bar plot for Iris-Versicolor:-

# %% [markdown]
# ### Sample for bar_plot of iris-versicolor by taking 5 data

# %%
a=data[50:55]
a.plot.bar()
# Out:
# <AxesSubplot: xlabel='Species'>

# %% [markdown]
# ## Sepal_Length

# %%
m=list(data['SepalLength'])
print(m)
print(len(m))
#for Sepal-Length of Iris-Versicolor
n=m[50:100]
print(n)
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar')
plt.legend("SL")
plt.show()
# Out:
# [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5.0, 5.5, 4.9, 4.4, 5.1, 5.0, 4.5, 4.4, 5.0, 5.1, 4.8, 5.1, 4.6, 5.3, 5.0, 7.0, 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5.0, 5.9, 6.0, 6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7, 6.0, 5.7, 5.5, 5.5, 5.8, 6.0, 5.4, 6.0, 6.7, 6.3, 5.6, 5.5, 5.5, 6.1, 5.8, 5.0, 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]
# 150
# ...

# %% [markdown]
# ## Sepal_Width

# %%
m=list(data['SepalWidth'])
print(len(m))
n=m[50:100] #for Sepal-Width of Iris-Versicolor
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['orange'])
plt.legend("SW")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# ## Petal_Length

# %%
m=list(data['PetalLength'])
print(len(m))
n=m[50:100] #for Petal-Length of Iris-Versicolor
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['green'])
plt.legend("PL")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# ## Petal_Width

# %%
m=list(data['PetalWidth'])
print(len(m))
#for Petal-Width of Iris-Versicolor
n=m[50:100]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['red'])
plt.legend("PW")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# # Bar plot for Iris-Virginica:-

# %% [markdown]
# ### Sample for bar_plot of iris-virginica by taking 5 data

# %%
a=data[100:105]
a.plot.bar()
# Out:
# <AxesSubplot: xlabel='Species'>

# %% [markdown]
# ## Sepal_Length

# %%
m=list(data['SepalLength'])
print(m)
print(len(m))
n=m[100:150] #for Sepal-Length of Iris-Virginica
print(n)
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar')
plt.legend("SL")
plt.show()
# Out:
# [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5.0, 5.5, 4.9, 4.4, 5.1, 5.0, 4.5, 4.4, 5.0, 5.1, 4.8, 5.1, 4.6, 5.3, 5.0, 7.0, 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5.0, 5.9, 6.0, 6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7, 6.0, 5.7, 5.5, 5.5, 5.8, 6.0, 5.4, 6.0, 6.7, 6.3, 5.6, 5.5, 5.5, 6.1, 5.8, 5.0, 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]
# 150
# ...

# %% [markdown]
# ## Sepal_Width

# %%
m=list(data['SepalWidth'])
print(len(m))
n=m[50:100] #for Sepal-Width of Iris-Virginica
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['orange'])
plt.legend("SW")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# ## Petal_Length

# %%
m=list(data['PetalLength'])
print(len(m))
n=m[50:100] #for Petal-Length of Iris-Virginica
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['green'])
plt.legend("PL")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# ## Petal_Width

# %%
m=list(data['PetalWidth'])
print(len(m))
#for Petal-Width of Iris-Versicolor
n=m[50:100]
print(len(n))
n = pd.DataFrame(n)
n.plot(kind='bar', color=['red'])
plt.legend("PW")
plt.show()
# Out:
# 150
# 50

# %% [markdown]
# # Density

# %%
data.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
data['SepalLength'].plot.kde()
plt.xlabel('SepalLength')
# Out:
# Text(0.5, 0, 'SepalLength')

# %%
data['SepalWidth'].plot.kde()
plt.xlabel('SepalWidth')
# Out:
# Text(0.5, 0, 'SepalWidth')

# %%
data['PetalLength'].plot.kde()
plt.xlabel('PetalLength')
# Out:
# Text(0.5, 0, 'PetalLength')

# %%
data['PetalWidth'].plot.kde()
plt.xlabel('PetalWidth')
# Out:
# Text(0.5, 0, 'PetalWidth')

# %% [markdown]
# ## Density of Iris-Setosa

# %%
n=data[0:50]
n.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## Density of Iris-Versicolor

# %%
n=data[50:100]
n.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## Density of Iris-Virginica

# %%
n=data[100:150]
n.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# # THANKYOU
